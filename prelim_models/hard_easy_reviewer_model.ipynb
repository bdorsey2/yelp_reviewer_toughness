# %%
import sys
import json
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
import string

# %%
review_fn = "/Users/evan/msds_main/machine_learning_1/yelp/yelp_dataset/yelp_academic_dataset_review.json"

with open(review_fn, 'r', encoding='UTF-8') as f:
    rev_data = f.readlines()
    # this line below may take at least 8-10 minutes of processing for 4-5 million rows. It converts all strings in list to actual json objects. 
    rev_data = list(map(json.loads, rev_data))
    
rev_df = pd.DataFrame(rev_data)

business_fn = '/Users/evan/msds_main/machine_learning_1/yelp/yelp_dataset/yelp_academic_dataset_business.json'

with open(business_fn, 'r', encoding='UTF-8') as f:
    bus_data = f.readlines()
    # this line below may take at least 8-10 minutes of processing for 4-5 million rows. It converts all strings in list to actual json objects. 
    bus_data = list(map(json.loads, bus_data))

# %%
bus_df = pd.DataFrame(bus_data)[['business_id','categories','attributes','city','name','review_count','stars']]

# %%
rev_df.rename(columns = {'stars':'review_stars'}, inplace = True)
bus_df.rename(columns = {'stars':'rest_stars'}, inplace = True)
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25      0  x7mDIiDB3jEiPGPHOmDzyw
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 3  elqbBhBfElMNSrjFqW3now     0  2011-02-25      0  Er4NBWCmCD4nM8_p1GRdow
# 4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
#
#    review_stars                                               text  useful  \
# 0             2  The pizza was okay. Not the best I've had. I p...       0
# 1             5  I love this place! My fiance And I go here atl...       0
# 2             1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 3             2  Back in 2005-2007 this place was my FAVORITE t...       2
# 4             5  Delicious healthy food. The steak is amazing. ...       0
#
#                   user_id
# 0  msQe1u7Z_XuqjGoqhB0J5g
# 1  msQe1u7Z_XuqjGoqhB0J5g
# 2  msQe1u7Z_XuqjGoqhB0J5g
# 3  msQe1u7Z_XuqjGoqhB0J5g
# 4  msQe1u7Z_XuqjGoqhB0J5g

# %%
bus_df = bus_df[bus_df.categories.str.contains('Restaurant|Food', na=False)]
bus_df = bus_df[bus_df.review_count > 25]

# %%
# Create happy hour label from attributes data
# bus_df['happy_hour'] = [True if attrs is not None and "HappyHour" in attrs and attrs["HappyHour"] == "True" else False for attrs in bus_df['attributes']]

# %%
rest_df = rev_df.merge(bus_df, how='inner', left_on='business_id', right_on='business_id')
# Out:
#               business_id     cool     date    funny  review_id     text  \
# review_stars
# 0                       1        1        1        1          1        1
# 1                  465405   465405   465405   465405     465405   465405
# 2                  373063   373063   373063   373063     373063   373063
# 3                  539889   539889   539889   539889     539889   539889
# 4                 1064126  1064126  1064126  1064126    1064126  1064126
# 5                 1576241  1576241  1576241  1576241    1576241  1576241
#
#                useful  user_id  categories  attributes     city     name  \
# review_stars
# 0                   1        1           1           1        1        1
# 1              465405   465405      465405      463208   465405   465405
# 2              373063   373063      373063      372072   373063   373063
# 3              539889   539889      539889      538601   539889   539889
# 4             1064126  1064126     1064126     1061977  1064126  1064126
# 5             1576241  1576241     1576241     1572090  1576241  1576241
#
#               review_count  rest_stars  happy_hour
# review_stars
# 0                        1           1           1
# 1                   465405      465405      465405
# 2                   373063      373063      373063
# 3                   539889      539889      539889
# 4                  1064126     1064126     1064126
# 5                  1576241     1576241     1576241

# %%
rest_df['user_review_count'] = df.groupby(['user_id'])['review_id'].transform('count')
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25      0  x7mDIiDB3jEiPGPHOmDzyw
# 1  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-10-25      0  VluIpojME0yKOcRKI5L0Iw
# 2  iCQpiavjjPzJ5_3gPD5Ebg     0  2016-05-22      0  nsB9JAeghk0zOaSulSm9Yw
# 3  iCQpiavjjPzJ5_3gPD5Ebg     0  2014-12-30      0  pcn01EMERpCpHEcoaohdEg
# 4  iCQpiavjjPzJ5_3gPD5Ebg     0  2013-03-24      0  0mFtAPTmInbXHqDjX9eiOg
#
#    review_stars                                               text  useful  \
# 0             2  The pizza was okay. Not the best I've had. I p...       0
# 1             3  came here on Monday, no line. its good, but no...       0
# 2             5  This place is truly a secret!  Its so hidden t...       0
# 3             5  This SECRET  PIZZA was a secret for about 5 st...       0
# 4             5  this is the BEST place to grab a quick slice o...       0
#
#                   user_id          categories  \
# 0  msQe1u7Z_XuqjGoqhB0J5g  Pizza, Restaurants
# 1  D1_nrBr4dOrs7M82OaBRwQ  Pizza, Restaurants
# 2  jEjc8HxeCeI22M4di0Y1aw  Pizza, Restaurants
# 3  RTiaaHSN80VRTLSdNK5rfQ  Pizza, Restaurants
# 4  hBmJs49zYcXdV4wo8F5iiA  Pizza, Restaurants
#
#                                           attributes       city          name  \
# 0  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 1  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 2  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 3  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 4  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
#
#    review_count  rest_stars  happy_hour  stars_delta  avg_star_delta  \
# 0           9.0         4.0       False         -2.0         -0.5000
# 1           8.0         4.0       False         -1.0          0.5625
# 2           1.0         4.0       False          1.0          1.0000
# 3           1.0         4.0       False          1.0          1.0000
# 4           5.0         4.0       False          1.0         -0.1000
#
#    user_review_count
# 0                9.0
# 1                8.0
# 2                1.0
# 3                1.0
# 4                5.0

# %%
rest_df['stars_delta'] = rest_df.review_stars - rest_df.rest_stars
rest_df['avg_star_delta'] = rest_df.groupby(['user_id'])['stars_delta'].transform('mean')
rest_df.head()
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25      0  x7mDIiDB3jEiPGPHOmDzyw
# 1  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-10-25      0  VluIpojME0yKOcRKI5L0Iw
# 2  iCQpiavjjPzJ5_3gPD5Ebg     0  2016-05-22      0  nsB9JAeghk0zOaSulSm9Yw
# 3  iCQpiavjjPzJ5_3gPD5Ebg     0  2014-12-30      0  pcn01EMERpCpHEcoaohdEg
# 4  iCQpiavjjPzJ5_3gPD5Ebg     0  2013-03-24      0  0mFtAPTmInbXHqDjX9eiOg
#
#    review_stars                                               text  useful  \
# 0             2  The pizza was okay. Not the best I've had. I p...       0
# 1             3  came here on Monday, no line. its good, but no...       0
# 2             5  This place is truly a secret!  Its so hidden t...       0
# 3             5  This SECRET  PIZZA was a secret for about 5 st...       0
# 4             5  this is the BEST place to grab a quick slice o...       0
#
#                   user_id          categories  \
# 0  msQe1u7Z_XuqjGoqhB0J5g  Pizza, Restaurants
# 1  D1_nrBr4dOrs7M82OaBRwQ  Pizza, Restaurants
# 2  jEjc8HxeCeI22M4di0Y1aw  Pizza, Restaurants
# 3  RTiaaHSN80VRTLSdNK5rfQ  Pizza, Restaurants
# 4  hBmJs49zYcXdV4wo8F5iiA  Pizza, Restaurants
#
#                                           attributes       city          name  \
# 0  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 1  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 2  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 3  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
# 4  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  Las Vegas  Secret Pizza
#
#    review_count  rest_stars  happy_hour  stars_delta  avg_star_delta  \
# 0           9.0         4.0       False         -2.0         -0.5000
# 1           8.0         4.0       False         -1.0          0.5625
# 2           1.0         4.0       False          1.0          1.0000
# 3           1.0         4.0       False          1.0          1.0000
# 4           5.0         4.0       False          1.0         -0.1000
#
#    user_review_count
# 0                9.0
# 1                8.0
# 2                1.0
# 3                1.0
# 4                5.0

# %%
# tried unsuccesfully to create histograms for user_review_count and avg_star_delta
# rest_df.groupby('user_id')['user_review_count'].value_counts().hist(bins = 100)
# rest_df.hist(column = 'user_id')
# rest_df.groupby('user_id')['avg_star_delta'].value_counts().hist()

# %%
# reduce dataframe to only include reviews from users with between 5 and 20 reviews
rest_df2 = rest_df[(rest_df.user_review_count > 5) & (rest_df.user_review_count < 20)]
len(rest_df2)/len(rest_df)
# Out:
# 0.23838879246527195

# %%
# calculates number of reviews per category
hard = len(rest_df2[(rest_df2['avg_star_delta']<-0.5)])
med = len(rest_df2[(rest_df2['avg_star_delta']<= 0.5) & (rest_df2['avg_star_delta']>= -0.5)])
easy = len(rest_df2[(rest_df2['avg_star_delta']>0.5)])
print(hard)
print(med)
print(easy)
print(len(rest_df2))
# Out:
# 156092
# 618461
# 183466
# 958019

# %%
df = rest_df2.loc[:,['review_id', 'user_id', 'text', 'avg_star_delta', 'user_review_count']]
# check at some point to make sure all review_id's are unique

df['text'] = df['text'].astype(str)

# Group data by user_id and combine review text
grouped = df.groupby(['user_id', 'avg_star_delta'])['text'].sum()

# %%
# Fix dataframe format and indexing
df_by_user = pd.DataFrame(grouped)
df_by_user = grouped_df.add_suffix('_aggregated').reset_index()
df_by_user.head()
# Out:
#                   user_id  avg_star_delta  \
# 0  --3WaS23LcIXtxyFULJHTA       -0.318182
# 1  --4rAAfZnEIAKJE80aIiYg       -0.947368
# 2  --CIuK7sUpaNzalLAlHJKA        0.333333
# 3  --DxiDMQgN08E5gTM0aj7Q       -1.083333
# 4  --HCoE1ghaAlcaAfshICgw        0.900000
#
#                                      text_aggregated
# 0  Ummm, due to the star ratings on Yelp we made ...
# 1  In my opinion, this restaurant has the best fo...
# 2  All is right with the world. After going to th...
# 3  I went to this sushi place because of its high...
# 4  One of the best buffets I have been to for the...

# %%
# create easy/hard reviewer labels
df_by_user['reviewer_label'] = pd.cut(df_by_user['avg_star_delta'], bins=[-5,-0.5,.5,5], include_lowest=False, labels=['hard', 'med', 'easy'])
df_by_user.head()
# Out:
#                   user_id  avg_star_delta  \
# 0  --3WaS23LcIXtxyFULJHTA       -0.318182
# 1  --4rAAfZnEIAKJE80aIiYg       -0.947368
# 2  --CIuK7sUpaNzalLAlHJKA        0.333333
# 3  --DxiDMQgN08E5gTM0aj7Q       -1.083333
# 4  --HCoE1ghaAlcaAfshICgw        0.900000
#
#                                      text_aggregated reviewer_label
# 0  Ummm, due to the star ratings on Yelp we made ...         medium
# 1  In my opinion, this restaurant has the best fo...           hard
# 2  All is right with the world. After going to th...         medium
# 3  I went to this sushi place because of its high...           hard
# 4  One of the best buffets I have been to for the...           easy

# %%
hard = sum(df_by_user['reviewer_label'] == 'hard')
med = sum(df_by_user['reviewer_label'] == 'med')
easy = sum(df_by_user['reviewer_label'] == 'easy')
print(hard)
print(med)
print(easy)
print(med/len(df_by_user))
# Out:
# 20597
# 0
# 21937
# 0.0

# %%
train_data, test_data, train_target, test_target = train_test_split(df_by_user['text_aggregated'],
                                                                    df_by_user['reviewer_label'])

# %%
str_test_data = []
for text in test_data:
    str_test_data.append(str(text))

# %%
str_train_data = []
for text in train_data:
    str_train_data.append(str(text))

# %%
vectorizer = TfidfVectorizer(stop_words='english', binary=True, ngram_range=(1,2)) 
train_features = vectorizer.fit_transform(str_train_data)
test_features = vectorizer.transform(str_test_data)

# %%
model = LogisticRegression(C=1e9, solver='lbfgs', multi_class='multinomial', random_state=0)
model.fit(train_features, train_target)
predicted = model.predict(test_features)
    
accuracy = accuracy_score(predicted, test_target)
# Out:
# /Users/evan/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
accuracy
# Out:
# 0.7066456508192515

# %%
model2 = LinearSVC(fit_intercept=True, random_state=0)
model2.fit(train_features, train_target)
predicted2 = model2.predict(test_features)
    
accuracy2 = accuracy_score(predicted2, test_target)

# %%
accuracy2
# Out:
# 0.6901873098493457

# %%
# this code saves to csv and loads it back in a weird format with messed up review_stars values
# rest_df.to_csv('show_me_the_data/yelp_business_and_reviews', sep='\t', encoding='utf-8')
# df = pd.read_csv('show_me_the_data/yelp_business_and_reviews',sep='\t',index_col=0, encoding='utf-8')
# df.review_stars.unique()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-25-50e548629eda> in <module>
# ----> 1 rest_df.to_csv('show_me_the_data/yelp_business_and_reviews', sep='\t', encoding='ascii')
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     169                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     170
# --> 171             self._save()
#     172
#     173         finally:
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save(self)
#     284                 break
#     285
# --> 286             self._save_chunk(start_i, end_i)
#     287
#     288     def _save_chunk(self, start_i, end_i):
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         libwriters.write_csv_rows(self.data, ix, self.nlevels,
# --> 313                                   self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'ascii' codec can't encode character '\xe0' in position 146: ordinal not in range(128)
