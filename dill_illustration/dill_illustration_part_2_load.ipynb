# %%
import pandas as pd
import pickle

# %%
filename = 'biz_df_head'

# %%
# Load the data frame
infile = open(filename, 'rb')
biz_df_head = pickle.load(infile)
infile.close()

# %%
biz_df_head
# Out:
#                                                   address  \
# 0                                       1314 44 Avenue NE
# 1
# 2                                     1335 rue Beaubien E
# 3                                         211 W Monroe St
# 4                                     2005 Alyth Place SE
# 5                         20235 N Cave Creek Rd, Ste 1115
# 6                                          631 Bloor St W
# 7                             3417 Derry Road E, Unit 103
# 8                                      1440 N. Dysart Ave
# 9                                         209 Oakland Ave
# 10                                       4568 Highway 7 E
# 11                                     595 Markham Street
# 12                                        2801 N 15th Ave
# 13                                4216 Saint-Laurent Boul
# 14                                      4404 14 Street NW
# 15                                          1200 37 St SW
# ...
