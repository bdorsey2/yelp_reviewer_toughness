# %%
import sys
import json
import pandas as pd
from collections import Counter

# %%
filename = "yelp_academic_dataset_business.json"

with open(filename, 'r', encoding='UTF-8') as f:
    data = f.readlines()
    # this line below may take at least 8-10 minutes of processing for 4-5 million rows. It converts all strings in list to actual json objects. 
    data = list(map(json.loads, data))
    
biz_df = pd.DataFrame(data)

# %%
biz_df.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                       {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 3      211 W Monroe St                                               None
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
#         city                                              hours  is_open  \
# 0    Calgary  {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...        1
# 1  Henderson  {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...        0
# 2   Montréal  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...        0
# 3    Phoenix                                               None        1
# 4    Calgary  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1
#
#     latitude   longitude                  name               neighborhood  \
# 0  51.091813 -114.031675  Minhas Micro Brewery
# 1  35.960734 -114.939821   CK'S BBQ & Catering
# 2  45.540503  -73.599300         La Bastringue  Rosemont-La Petite-Patrie
# 3  33.449999 -112.076979       Geico Insurance
# 4  51.035591 -114.027366         Action Engine
#
#   postal_code  review_count  stars state
# 0     T2E 6L6            24    4.0    AB
# 1       89002             3    4.5    NV
# 2     H2G 1K7             5    4.0    QC
# 3       85003             8    1.5    AZ
# 4     T2H 0N5             4    2.0    AB

# %%
biz_df.shape
# Out:
# (188593, 15)

# %%
biz_df["categories"][0:10]
# Out:
# 0    Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1    Chicken Wings, Burgers, Caterers, Street Vendo...
# 2    Breakfast & Brunch, Restaurants, French, Sandw...
# 3                        Insurance, Financial Services
# 4    Home & Garden, Nurseries & Gardening, Shopping...
# 5                                   Coffee & Tea, Food
# 6                                       Food, Bakeries
# 7                                    Restaurants, Thai
# 8                                 Mexican, Restaurants
# 9                Flowers & Gifts, Gift Shops, Shopping
# Name: categories, dtype: object

# %%
categories_in_biz_df = list(biz_df["categories"])
len(categories_in_biz_df)  # Number of businesses on this data sheet
# Out:
# 188593

# %%
"""
*** Add i to create list of 1's and 0's for the purpose of filtering
"""
qualified_res_count = 0
categories_restaurant = []
target = "Restaurants"
avoid = "Restaurant Supplies"
filter_list = []
for element in categories_in_biz_df:
    if type(element) == str:  # There are some cases the type of the value is not str 
        if target in element and avoid not in element:
            qualified_res_count += 1
            filter_list.append(1)
            temp_list = element.split(", ")
            for category in temp_list:
                categories_restaurant.append(category)
        else: 
            filter_list.append(0)
    else:
        filter_list.append(0)

# %%
qualified_res_count  # Number of restaurants on this data sheet
# Out:
# 57169

# %%
biz_df['Restaurants'] = filter_list
biz_df_restaurants = biz_df.loc[biz_df['Restaurants'] == 1]
biz_df_restaurants.shape
# Out:
# (57169, 16)

# %%
len(categories_restaurant)
# Out:
# 227053

# %%
len(set(categories_restaurant))  # Number of categories (uncleaned)
# Out:
# 705

# %%
categories_restaurant_dict = dict(Counter(categories_restaurant))
categories_restaurant_counter_list = []
for key in categories_restaurant_dict:
    categories_restaurant_counter_list.append([key, categories_restaurant_dict[key]])
categories_restaurant_counter_list.sort(key=lambda x: x[1], reverse = True)
"""
As you can see below, when you scroll down to the bottom,
some weird categories pop up, such as "Hookah Bars" and "Beauty & Spas". 
Therefore, there is a need to set a threshold or use alternative way to clean.
"""
categories_restaurant_counter_list  # Categories and their occurence in descending order
# Out:
# [['Restaurants', 57169],
#  ['Food', 11665],
#  ['Nightlife', 7948],
#  ['Bars', 7646],
#  ['Sandwiches', 6912],
#  ['Fast Food', 6812],
#  ['American (Traditional)', 6659],
#  ['Pizza', 6603],
#  ['Burgers', 5126],
#  ['Breakfast & Brunch', 5023],
#  ['Italian', 4550],
#  ['Mexican', 4419],
#  ['Chinese', 4247],
#  ['American (New)', 4230],
#  ['Coffee & Tea', 3108],
#  ['Cafes', 3056],
#  ['Japanese', 2566],
#  ['Chicken Wings', 2538],
#  ['Seafood', 2369],
#  ['Salad', 2350],
#  ['Event Planning & Services', 2247],
#  ['Sushi Bars', 2156],
#  ['Delis', 1835],
#  ['Canadian (New)', 1828],
#  ['Asian Fusion', 1780],
#  ['Mediterranean', 1744],
#  ['Barbeque', 1716],
#  ['Sports Bars', 1665],
#  ['Specialty Food', 1587],
#  ['Caterers', 1556],
#  ['Steakhouses', 1531],
#  ['Desserts', 1434],
#  ['Bakeries', 1418],
#  ['Indian', 1417],
#  ['Thai', 1393],
#  ['Pubs', 1382],
#  ['Diners', 1351],
#  ['Vietnamese', 1225],
#  ['Middle Eastern', 1182],
#  ['Greek', 1023],
#  ['Vegetarian', 1017],
#  ['French', 977],
#  ['Wine Bars', 916],
#  ['Cocktail Bars', 849],
#  ['Ice Cream & Frozen Yogurt', 848],
#  ['Korean', 847],
#  ['Beer', 845],
#  ['Wine & Spirits', 845],
#  ['Buffets', 837],
#  ['Arts & Entertainment', 816],
#  ['Lounges', 798],
#  ['Comfort Food', 793],
#  ['Gluten-Free', 787],
#  ['Soup', 778],
#  ['Juice Bars & Smoothies', 760],
#  ['Vegan', 741],
#  ['Hot Dogs', 699],
#  ['Tex-Mex', 695],
#  ['Ethnic Food', 630],
#  ['Caribbean', 604],
#  ['Food Delivery Services', 600],
#  ['Food Trucks', 559],
#  ['Halal', 549],
#  ['Latin American', 547],
#  ['Gastropubs', 513],
#  ['Chicken Shop', 513],
#  ['Southern', 493],
#  ['Grocery', 471],
#  ['Venues & Event Spaces', 468],
#  ['Shopping', 442],
#  ['Tapas/Small Plates', 428],
#  ['Noodles', 411],
#  ['Pakistani', 397],
#  ['Bagels', 394],
#  ['Tapas Bars', 369],
#  ['Music Venues', 342],
#  ['Fish & Chips', 313],
#  ['Hotels & Travel', 308],
#  ['Hawaiian', 304],
#  ['Beer Bar', 302],
#  ['Food Stands', 298],
#  ['Imported Food', 294],
#  ['Soul Food', 294],
#  ['Dim Sum', 281],
#  ['Cajun/Creole', 274],
#  ['Creperies', 247],
#  ['Breweries', 243],
#  ['Portuguese', 242],
#  ['Dive Bars', 235],
#  ['Active Life', 234],
#  ['Tacos', 228],
#  ['Filipino', 219],
#  ['Lebanese', 218],
#  ['Hotels', 209],
#  ['Ramen', 209],
#  ['Donuts', 205],
#  ['Modern European', 204],
#  ['Taiwanese', 203],
#  ['Cheesesteaks', 198],
#  ['Street Vendors', 196],
#  ['Irish', 195],
#  ['Spanish', 181],
#  ['Persian/Iranian', 176],
#  ['Karaoke', 174],
#  ['Local Flavor', 173],
#  ['Poutineries', 170],
#  ['Food Court', 167],
#  ['Tea Rooms', 163],
#  ['Meat Shops', 162],
#  ['German', 158],
#  ['Bubble Tea', 158],
#  ['Dance Clubs', 158],
#  ['British', 149],
#  ['African', 139],
#  ['Party & Event Planning', 137],
#  ['Poke', 136],
#  ['Bistros', 135],
#  ['Health Markets', 129],
#  ['Brasseries', 129],
#  ['Falafel', 128],
#  ['Turkish', 127],
#  ['Wraps', 126],
#  ['Hookah Bars', 124],
#  ['Afghan', 118],
#  ['Kosher', 118],
#  ['Convenience Stores', 117],
#  ['Hot Pot', 113],
#  ['Casinos', 110],
#  ['Peruvian', 105],
#  ['Waffles', 103],
#  ['Szechuan', 89],
#  ['Cantonese', 88],
#  ['Internet Cafes', 85],
#  ['Brazilian', 83],
#  ['Irish Pub', 82],
#  ['Delicatessen', 82],
#  ['Ethiopian', 81],
#  ['Cuban', 78],
#  ['Arcades', 78],
#  ['Coffee Roasteries', 75],
#  ['Pan Asian', 75],
#  ['Seafood Markets', 74],
#  ['Golf', 72],
#  ['Malaysian', 72],
#  ['Patisserie/Cake Shop', 71],
#  ['Automotive', 70],
#  ['Beauty & Spas', 70],
#  ['Moroccan', 70],
#  ['Polish', 70],
#  ['Butcher', 69],
#  ['Live/Raw Food', 69],
#  ['Do-It-Yourself Food', 68],
#  ['Local Services', 66],
#  ['Arabian', 66],
#  ['Salvadoran', 66],
#  ['Pasta Shops', 65],
#  ['Jazz & Blues', 64],
#  ['Home & Garden', 63],
#  ['Farmers Market', 63],
#  ['Donairs', 60],
#  ['Bed & Breakfast', 59],
#  ['Organic Stores', 59],
#  ['Pool Halls', 59],
#  ['Russian', 57],
#  ['Shopping Centers', 56],
#  ['Kebab', 56],
#  ['Cheese Shops', 56],
#  ['Chocolatiers & Shops', 55],
#  ['Shaved Ice', 54],
#  ['Flowers & Gifts', 54],
#  ['Fruits & Veggies', 53],
#  ['International Grocery', 53],
#  ['Himalayan/Nepalese', 53],
#  ['Smokehouse', 52],
#  ['Gelato', 51],
#  ['Home Services', 50],
#  ['Belgian', 49],
#  ['New Mexican Cuisine', 49],
#  ['Health & Medical', 48],
#  ['Mongolian', 48],
#  ['Acai Bowls', 48],
#  ['Fondue', 47],
#  ['Education', 47],
#  ['International', 46],
#  ['Fashion', 46],
#  ['Beer Gardens', 46],
#  ['Colombian', 46],
#  ['Argentine', 45],
#  ['Cupcakes', 44],
#  ['Bowling', 43],
#  ['Cafeteria', 42],
#  ['Gas Stations', 41],
#  ['Performing Arts', 40],
#  ['Custom Cakes', 40],
#  ['Cambodian', 38],
#  ['Festivals', 37],
#  ['Wineries', 36],
#  ['Sri Lankan', 35],
#  ['Hakka', 35],
#  ['Pretzels', 35],
#  ['Brewpubs', 34],
#  ['Art Galleries', 34],
#  ['Whiskey Bars', 32],
#  ['Hungarian', 31],
#  ['Arts & Crafts', 30],
#  ['Personal Chefs', 29],
#  ['Teppanyaki', 28],
#  ['Wedding Planning', 27],
#  ['Venezuelan', 27],
#  ['Professional Services', 27],
#  ['Books', 27],
#  ['Mags', 27],
#  ['Music & Video', 27],
#  ['Indonesian', 27],
#  ['Specialty Schools', 27],
#  ['Singaporean', 26],
#  ['Gift Shops', 26],
#  ['Social Clubs', 26],
#  ['Day Spas', 25],
#  ['Public Services & Government', 25],
#  ['Adult Entertainment', 25],
#  ['Puerto Rican', 25],
#  ['Ukrainian', 24],
#  ['Hair Salons', 24],
#  ['Resorts', 23],
#  ['Basque', 23],
#  ['Cinema', 22],
#  ['Candy Stores', 22],
#  ['Gay Bars', 22],
#  ['Fitness & Instruction', 21],
#  ['Kids Activities', 21],
#  ['Tours', 20],
#  ['Pets', 19],
#  ['Florists', 19],
#  ['Bangladeshi', 19],
#  ['South African', 19],
#  ['Egyptian', 19],
#  ['Laotian', 19],
#  ['Drugstores', 18],
#  ['Department Stores', 18],
#  ['Kitchen & Bath', 18],
#  ['Dominican', 17],
#  ['Dinner Theater', 17],
#  ['Real Estate', 17],
#  ['Cooking Schools', 17],
#  ['Home Decor', 16],
#  ['Izakaya', 16],
#  ['Ethnic Grocery', 16],
#  ['Wigs', 16],
#  ['Speakeasies', 16],
#  ['Macarons', 15],
#  ['Furniture Stores', 15],
#  ['Playgrounds', 14],
#  ['Comedy Clubs', 14],
#  ['Country Clubs', 13],
#  ['Amusement Parks', 13],
#  ['Nutritionists', 13],
#  ['Cooking Classes', 13],
#  ['Tobacco Shops', 13],
#  ['Bookstores', 13],
#  ["Women's Clothing", 13],
#  ['Haitian', 13],
#  ['Appliances', 13],
#  ['Swimming Pools', 12],
#  ['Community Service/Non-Profit', 12],
#  ['Eatertainment', 12],
#  ['Empanadas', 12],
#  ['Cosmetics & Beauty Supply', 12],
#  ['Sporting Goods', 12],
#  ['Piano Bars', 12],
#  ['Scandinavian', 11],
#  ['Art Classes', 11],
#  ['Recreation Centers', 11],
#  ['Nail Salons', 11],
#  ['Ethical Grocery', 11],
#  ['Burmese', 11],
#  ['Beverage Store', 11],
#  ['Sports Clubs', 11],
#  ['Country Dance Halls', 10],
#  ['Hobby Shops', 10],
#  ['Museums', 10],
#  ['Bavarian', 10],
#  ['Landmarks & Historical Buildings', 10],
#  ['Pharmacy', 10],
#  ['Australian', 10],
#  ['Shanghainese', 10],
#  ['Public Markets', 10],
#  ['Pet Services', 9],
#  ['Couriers & Delivery Services', 9],
#  ['Vitamins & Supplements', 9],
#  ['Auto Repair', 9],
#  ['Tabletop Games', 9],
#  ['Outlet Stores', 9],
#  ['Contractors', 9],
#  ['Supper Clubs', 8],
#  ['Parks', 8],
#  ['Libraries', 8],
#  ['Armenian', 8],
#  ['Massage', 8],
#  ['Beer Garden', 8],
#  ['Coffee & Tea Supplies', 8],
#  ['Syrian', 8],
#  ['Musicians', 8],
#  ['Airports', 8],
#  ['Financial Services', 8],
#  ['Toy Stores', 7],
#  ['Themed Cafes', 7],
#  ['Sugar Shacks', 7],
#  ['Religious Organizations', 7],
#  ['Pop-Up Restaurants', 7],
#  ['Austrian', 7],
#  ["Men's Clothing", 7],
#  ['Hair Removal', 7],
#  ['Art Schools', 7],
#  ['DJs', 7],
#  ['Laser Tag', 7],
#  ['Outdoor Furniture Stores', 7],
#  ['Wine Tasting Room', 7],
#  ['Tiki Bars', 7],
#  ['Dry Cleaning & Laundry', 6],
#  ['Pet Stores', 6],
#  ['Nurseries & Gardening', 6],
#  ['Food Tours', 6],
#  ['Herbs & Spices', 6],
#  ['Popcorn Shops', 6],
#  ['Colleges & Universities', 6],
#  ['Tuscan', 6],
#  ['Doctors', 6],
#  ['Transportation', 6],
#  ['Pet Sitting', 6],
#  ['Appliances & Repair', 6],
#  ['Palatine', 6],
#  ['Shared Office Spaces', 6],
#  ['Gyms', 6],
#  ['Mini Golf', 6],
#  ['Yelp Events', 6],
#  ['Weight Loss Centers', 6],
#  ['Czech', 6],
#  ['Champagne Bars', 6],
#  ['Travel Services', 5],
#  ['Beaches', 5],
#  ['Laundry Services', 5],
#  ['Towing', 5],
#  ['Barbers', 5],
#  ['Massage Therapy', 5],
#  ['Paint & Sip', 5],
#  ['Party Supplies', 5],
#  ['Eyelash Service', 5],
#  ['Bartenders', 5],
#  ['Trinidadian', 5],
#  ['Grilling Equipment', 5],
#  ['Vinyl Records', 5],
#  ['Trainers', 5],
#  ['Wholesale Stores', 5],
#  ['Plumbing', 5],
#  ['Mattresses', 5],
#  ['Iberian', 5],
#  ['Leisure Centers', 5],
#  ['Indoor Playcentre', 5],
#  ['Antiques', 5],
#  ['Yoga', 5],
#  ['Personal Shopping', 5],
#  ['Car Wash', 4],
#  ['Tennis', 4],
#  ['Amateur Sports Teams', 4],
#  ['Shoe Stores', 4],
#  ['Souvenir Shops', 4],
#  ['Golf Lessons', 4],
#  ['Distilleries', 4],
#  ['Slovakian', 4],
#  ['Stadiums & Arenas', 4],
#  ['Home Cleaning', 4],
#  ['Bike Rentals', 4],
#  ['Bike Repair/Maintenance', 4],
#  ['Strip Clubs', 4],
#  ['Sports Wear', 4],
#  ['Hair Stylists', 4],
#  ['Skin Care', 4],
#  ['Waxing', 4],
#  ['Scottish', 4],
#  ['Car Dealers', 4],
#  ['Honduran', 4],
#  ['Airport Lounges', 4],
#  ['Cabaret', 4],
#  ['Interior Design', 4],
#  ['Pub Food', 4],
#  ['Real Estate Services', 4],
#  ['Accessories', 4],
#  ['Heating & Air Conditioning/HVAC', 4],
#  ['Videos & Video Game Rental', 4],
#  ['Jewelry', 3],
#  ['Zoos', 3],
#  ['Discount Store', 3],
#  ['Boating', 3],
#  ['RV Parks', 3],
#  ['Hong Kong Style Cafe', 3],
#  ['Life Coach', 3],
#  ['Medical Spas', 3],
#  ['Team Building Activities', 3],
#  ['Coffeeshops', 3],
#  ['Pool & Billiards', 3],
#  ['Guest Houses', 3],
#  ['Horseback Riding', 3],
#  ['Bikes', 3],
#  ['Cideries', 3],
#  ['Community Centers', 3],
#  ['Party Equipment Rentals', 3],
#  ['Marketing', 3],
#  ['Screen Printing', 3],
#  ['Web Design', 3],
#  ['Tanning', 3],
#  ['Escape Games', 3],
#  ['Shaved Snow', 3],
#  ['Marinas', 3],
#  ['Makeup Artists', 3],
#  ['Animal Shelters', 3],
#  ['Uzbek', 3],
#  ['Tasting Classes', 3],
#  ['Walking Tours', 3],
#  ['Vape Shops', 3],
#  ['Hospitals', 3],
#  ['Churches', 3],
#  ['Fireplace Services', 3],
#  ['Bar Crawl', 3],
#  ['Conveyor Belt Sushi', 3],
#  ['Printing Services', 3],
#  ['Masonry/Concrete', 3],
#  ['Tires', 3],
#  ['Bankruptcy Law', 3],
#  ['Lawyers', 3],
#  ['Special Education', 3],
#  ['Nail Technicians', 3],
#  ['Business Consulting', 3],
#  ['Used', 3],
#  ['Vintage & Consignment', 3],
#  ['Flea Markets', 3],
#  ['Japanese Curry', 3],
#  ['Auto Glass Services', 3],
#  ['Soccer', 3],
#  ['Limos', 3],
#  ['Hiking', 2],
#  ['Laundromat', 2],
#  ['Aquariums', 2],
#  ['Local Fish Stores', 2],
#  ['Meditation Centers', 2],
#  ['Cultural Center', 2],
#  ['Botanical Gardens', 2],
#  ['Head Shops', 2],
#  ['Lakes', 2],
#  ['Landscaping', 2],
#  ['Race Tracks', 2],
#  ['Hair Extensions', 2],
#  ['Ski Resorts', 2],
#  ['Boat Charters', 2],
#  ['Music & DVDs', 2],
#  ['Advertising', 2],
#  ['Graphic Design', 2],
#  ['Ticket Sales', 2],
#  ['Laser Hair Removal', 2],
#  ['Cosmetic Surgeons', 2],
#  ['Spray Tanning', 2],
#  ['Pop-up Shops', 2],
#  ['Airport Shuttles', 2],
#  ['Electronics', 2],
#  ['Lighting Fixtures & Equipment', 2],
#  ['Furniture Rental', 2],
#  ['Photo Booth Rentals', 2],
#  ['Pet Groomers', 2],
#  ['Vacation Rentals', 2],
#  ['Olive Oil', 2],
#  ['Cards & Stationery', 2],
#  ['Cheese Tasting Classes', 2],
#  ['Air Duct Cleaning', 2],
#  ['Mauritius', 2],
#  ['Auto Parts & Supplies', 2],
#  ['Pet Adoption', 2],
#  ['Water Stores', 2],
#  ['Farms', 2],
#  ['Tax Services', 2],
#  ['Magicians', 2],
#  ['Banks & Credit Unions', 2],
#  ['Swiss Food', 2],
#  ['Home Health Care', 2],
#  ['Dentists', 2],
#  ['Pool & Hot Tub Service', 2],
#  ['Supernatural Readings', 2],
#  ['Horse Racing', 2],
#  ['Sicilian', 2],
#  ['Nicaraguan', 2],
#  ['Windows Installation', 2],
#  ['Roofing', 2],
#  ['Hotel bar', 2],
#  ['Bridal', 2],
#  ['CSA', 2],
#  ['Personal Assistants', 2],
#  ['Flooring', 2],
#  ['Adult Education', 2],
#  ['IT Services & Computer Repair', 2],
#  ['Auto Customization', 2],
#  ['Rock Climbing', 2],
#  ['Golf Equipment Shops', 2],
#  ['Property Management', 2],
#  ['Investing', 2],
#  ['Bingo Halls', 2],
#  ['Northern German', 2],
#  ['Climbing', 2],
#  ['Oil Change Stations', 2],
#  ['Computers', 2],
#  ['Reunion', 2],
#  ['Real Estate Agents', 2],
#  ['Body Shops', 2],
#  ['Pita', 2],
#  ['Wine Tours', 2],
#  ['Tattoo', 2],
#  ['Piercing', 2],
#  ['Wedding Chapels', 2],
#  ['Post Offices', 2],
#  ['Building Supplies', 2],
#  ['Art Supplies', 2],
#  ['Martial Arts', 2],
#  ['Party Bus Rentals', 2],
#  ['Apartments', 2],
#  ['Transmission Repair', 2],
#  ['Skating Rinks', 1],
#  ['Visitor Centers', 1],
#  ['Aquarium Services', 1],
#  ['Alternative Medicine', 1],
#  ['Leather Goods', 1],
#  ['Landscape Architects', 1],
#  ['Health Retreats', 1],
#  ['Eastern European', 1],
#  ['Comic Books', 1],
#  ['Milkshake Bars', 1],
#  ['University Housing', 1],
#  ['Mosques', 1],
#  ['Screen Printing/T-Shirt Printing', 1],
#  ['Counseling & Mental Health', 1],
#  ['Baguettes', 1],
#  ['Trophy Shops', 1],
#  ['Engraving', 1],
#  ['Guamanian', 1],
#  ['Sugaring', 1],
#  ['Taxis', 1],
#  ['Pensions', 1],
#  ['Mountain Biking', 1],
#  ['Rest Stops', 1],
#  ['Boat Dealers', 1],
#  ['Boat Repair', 1],
#  ['Ice Delivery', 1],
#  ['Audio/Visual Equipment Rental', 1],
#  ['Fur Clothing', 1],
#  ['Pilates', 1],
#  ['Furniture Repair', 1],
#  ['Opera & Ballet', 1],
#  ['Eyebrow Services', 1],
#  ['Bulgarian', 1],
#  ['Hainan', 1],
#  ['Honey', 1],
#  ['Photographers', 1],
#  ['Event Photography', 1],
#  ['Session Photography', 1],
#  ['Cigar Bars', 1],
#  ['Fire Protection Services', 1],
#  ['Office Cleaning', 1],
#  ['Senegalese', 1],
#  ['Summer Camps', 1],
#  ['Christmas Trees', 1],
#  ['Pumpkin Patches', 1],
#  ['Pick Your Own Farms', 1],
#  ['Skydiving', 1],
#  ['Accountants', 1],
#  ['Currency Exchange', 1],
#  ['Check Cashing/Pay-day Loans', 1],
#  ['Water Heater Installation/Repair', 1],
#  ['Septic Services', 1],
#  ['Mailbox Centers', 1],
#  ['Clowns', 1],
#  ['Signature Cuisine', 1],
#  ['Wine Tasting Classes', 1],
#  ['Reflexology', 1],
#  ['Occupational Therapy', 1],
#  ['Acupuncture', 1],
#  ['Physical Therapy', 1],
#  ['Rehabilitation Center', 1],
#  ['Newspapers & Magazines', 1],
#  ['Veterinarians', 1],
#  ['Day Camps', 1],
#  ['Teeth Whitening', 1],
#  ['General Dentistry', 1],
#  ['Cosmetic Dentists', 1],
#  ['Medical Transportation', 1],
#  ['Orthodontists', 1],
#  ['Hot Tub & Pool', 1],
#  ['Kombucha', 1],
#  ['Psychics', 1],
#  ['Game Meat', 1],
#  ['Siding', 1],
#  ['Parking', 1],
#  ['Personal Injury Law', 1],
#  ['Immigration Law', 1],
#  ['Divorce & Family Law', 1],
#  ['Dance Studios', 1],
#  ['Art Museums', 1],
#  ['Home Inspectors', 1],
#  ['Damage Restoration', 1],
#  ['Sailing', 1],
#  ['Electricians', 1],
#  ['Funeral Services & Cemeteries', 1],
#  ['Mobile Phone Repair', 1],
#  ['Auto Detailing', 1],
#  ['Motorcycle Repair', 1],
#  ['Auto Upholstery', 1],
#  ['Furniture Reupholstery', 1],
#  ['RV Repair', 1],
#  ['Czech/Slovakian', 1],
#  ['Airport Terminals', 1],
#  ['Trampoline Parks', 1],
#  ['Signmaking', 1],
#  ['Vehicle Wraps', 1],
#  ['Car Window Tinting', 1],
#  ['Rotisserie Chicken', 1],
#  ['Minho', 1],
#  ['Used Bookstore', 1],
#  ['Mortgage Brokers', 1],
#  ['Golf Equipment', 1],
#  ['Estate Liquidation', 1],
#  ['Traditional Norwegian', 1],
#  ['Paint-Your-Own Pottery', 1],
#  ['Security Systems', 1],
#  ['Mass Media', 1],
#  ['Print Media', 1],
#  ['Tonkatsu', 1],
#  ['Tempura', 1],
#  ['Dance Schools', 1],
#  ['Preschools', 1],
#  ['Baby Gear & Furniture', 1],
#  ['Bartending Schools', 1],
#  ['Feng Shui', 1],
#  ['Hardware Stores', 1],
#  ['Beer Hall', 1],
#  ['Family Practice', 1],
#  ['Public Transportation', 1],
#  ['Car Share Services', 1],
#  ['Wholesalers', 1],
#  ['Handyman', 1],
#  ['Foundation Repair', 1],
#  ['Dog Walkers', 1],
#  ['Pet Boarding', 1],
#  ['Churros', 1],
#  ['Bus Tours', 1],
#  ['Customized Merchandise', 1],
#  ['Cannabis Clinics', 1],
#  ['Kids Hair Salons', 1],
#  ['Video Game Stores', 1],
#  ['Thrift Stores', 1],
#  ['Fishmonger', 1],
#  ['Fishing', 1],
#  ['Truck Rental', 1],
#  ['Commercial Truck Repair', 1],
#  ['Clothing Rental', 1],
#  ['Soba', 1],
#  ['Campgrounds', 1],
#  ['Batting Cages', 1],
#  ['Udon', 1],
#  ['Hostels', 1],
#  ['Brazilian Jiu-jitsu', 1],
#  ['Drive-Thru Bars', 1],
#  ['Gardeners', 1],
#  ['Glass & Mirrors', 1],
#  ['Software Development', 1],
#  ['Door Sales/Installation', 1],
#  ['Go Karts', 1],
#  ['Parenting Classes', 1],
#  ['Keys & Locksmiths', 1],
#  ['Airsoft', 1],
#  ['Aircraft Repairs', 1],
#  ['Virtual Reality Centers', 1],
#  ['Club Crawl', 1],
#  ['Island Pub', 1],
#  ['Pawn Shops', 1],
#  ['Observatories', 1],
#  ['Unofficial Yelp Events', 1],
#  ['Mobile Phones', 1],
#  ['Gun/Rifle Ranges', 1],
#  ['Historical Tours', 1],
#  ['Medical Centers', 1],
#  ['Knife Sharpening', 1],
#  ['Cardiologists', 1],
#  ['Pediatricians', 1],
#  ['Emergency Medicine', 1],
#  ['Tai Chi', 1],
#  ['Estate Planning Law', 1],
#  ['Tax Law', 1],
#  ['Wills', 1],
#  ['Trusts', 1],
#  ['& Probates', 1],
#  ['Serbo Croatian', 1],
#  ['Chilean', 1],
#  ['Chiropractors', 1],
#  ['Insurance', 1],
#  ['Windshield Installation & Repair', 1],
#  ['Auto Insurance', 1],
#  ['Dry Cleaning', 1],
#  ['Security Services', 1],
#  ['Car Rental', 1]]

# %%
"""
Create dummy variables for categories
Once we decide the ways to clean the category list shown in the last section, 
then we can create dummy variable with the codes below.
"""
trial_df = biz_df_restaurants
categories_in_biz_df_restaurants = list(biz_df_restaurants["categories"])
#categories_set = set(categories_restaurant)
categories_set = ["Food", "Bars"]
for element in categories_set:
    dummy = []
    for i in range(len(categories_in_biz_df_restaurants)):
        if element in str(categories_in_biz_df_restaurants[i]):
            dummy.append(1)
        else:
            dummy.append(0)
    trial_df[element] = dummy
    print(element, "---", Counter(dummy))  # Test whether the number of occurence is correct
# Out:
# /Users/xulian/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Food --- Counter({0: 39161, 1: 18008})
# Bars --- Counter({0: 46576, 1: 10593})

# %%
trial_df.head()
# Out:
#                        address  \
# 0            1314 44 Avenue NE
# 1
# 2          1335 rue Beaubien E
# 7  3417 Derry Road E, Unit 103
# 8           1440 N. Dysart Ave
#
#                                           attributes             business_id  \
# 0  {'BikeParking': 'False', 'BusinessAcceptsCredi...  Apn5Q_b6Nz61Tq4XzPdf9A
# 1  {'Alcohol': 'none', 'BikeParking': 'False', 'B...  AjEbIBw6ZFfln7ePHha9PA
# 2  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...  O8S5hYJ1SMc8fA4QBtVujA
# 7  {'Alcohol': 'none', 'BusinessAcceptsCreditCard...  6OuOZAok8ikONMS_T3EzXg
# 8  {'Alcohol': 'none', 'Ambience': '{'romantic': ...  8-NRKkPY1UiFXW20WXKiXg
#
#                                           categories         city  \
# 0  Tours, Breweries, Pizza, Restaurants, Food, Ho...      Calgary
# 1  Chicken Wings, Burgers, Caterers, Street Vendo...    Henderson
# 2  Breakfast & Brunch, Restaurants, French, Sandw...     Montréal
# 7                                  Restaurants, Thai  Mississauga
# 8                               Mexican, Restaurants     Avondale
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...        1  51.091813
# 1  {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...        0  35.960734
# 2  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...        0  45.540503
# 7                                               None        1  43.712946
# 8  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.448106
#
#     longitude                      name               neighborhood  \
# 0 -114.031675      Minhas Micro Brewery
# 1 -114.939821       CK'S BBQ & Catering
# 2  -73.599300             La Bastringue  Rosemont-La Petite-Patrie
# 7  -79.632763               Thai One On                  Ridgewood
# 8 -112.341302  Filiberto's Mexican Food
#
#   postal_code  review_count  stars state  Restaurants  Food  Bars
# 0     T2E 6L6            24    4.0    AB            1     1     0
# 1       89002             3    4.5    NV            1     1     0
# 2     H2G 1K7             5    4.0    QC            1     0     0
# 7     L4T 1A8             7    2.0    ON            1     0     0
# 8       85323            40    2.5    AZ            1     0     0

# %%
#rest_df.to_csv('yelp_business_and_reviews', sep='\t', encoding='utf-8')
